# %%
from collections.abc import Callable
from os.path import join
from typing import Optional

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit

# depending on your IDE, you might need to add datathon_eth. in front of data
from data import DataLoader, DatasetEncoding, SimpleEncoding

# depending on your IDE, you might need to add datathon_eth. in front of forecast_models
from forecast_models import SimpleModel, elastic_net_predictor, lgbm_predictor


def evaluate_forecast(y_true, y_pred):
    diff = y_pred - y_true
    country_error = diff.abs().sum()
    portfolio_country_error = diff.sum()
    return country_error, abs(portfolio_country_error)


def cross_validate_forecaster(
    predictor: Callable,
    X: pd.DataFrame,
    y: pd.Series,
    verbose=True,
    save_path=None,
    n_splits=5,
):
    tscv = TimeSeriesSplit(n_splits=n_splits)
    all_absolute_errors = []
    all_portfolio_errors = []
    fold_scores = []

    for fold, (train_idx, test_idx) in enumerate(tscv.split(y.index), start=1):
        train_dates = pd.to_datetime(y.index[train_idx])
        test_dates = pd.to_datetime(y.index[test_idx])

        fold_abs_error = []
        fold_port_error = []

        if verbose:
            print(f"\n📦 Fold {fold}/{n_splits}")
            print(f"├─ Train range: {train_dates[0]} → {train_dates[-1]}  ({len(train_idx)} samples)")
            print(f"└─ Test  range: {test_dates[0]} → {test_dates[-1]}  ({len(test_idx)} samples)")

        y_train = y.loc[train_dates]
        y_test = y.loc[test_dates]

        X_train = X.loc[train_dates]
        X_test = X.loc[test_dates]

        if verbose:
            print("   ┌── Data shapes for first customer:")
            print(f"   │   X_train: {X_train.shape} | y_train: {y_train.shape}")
            print(f"   │   X_test : {X_test.shape} | y_test : {y_test.shape}")
            print("   └──────────────────────────────")

        if len(y_test) == 0:
            continue

        y_hat = predictor(X_train, y_train, X_test)

        country_err, portfolio_err = evaluate_forecast(y_test, y_hat)
        fold_abs_error.append(country_err)
        fold_port_error.append(portfolio_err)

        mean_fold_abs = np.mean(fold_abs_error)
        mean_fold_port = np.mean(fold_port_error)
        final_fold_score = 1.0 * mean_fold_abs + 5.0 * mean_fold_abs + 10.0 * mean_fold_port + 50.0 * mean_fold_port

        all_absolute_errors.append(mean_fold_abs)
        all_portfolio_errors.append(mean_fold_port)
        fold_scores.append(final_fold_score)

        if verbose:
            print(f"\n✅ Fold {fold} completed")
            print(f"   ├─ Mean Absolute Error (per customer):  {mean_fold_abs:.2f}")
            print(f"   ├─ Mean Portfolio Error (per customer): {mean_fold_port:.2f}")
            print(f"   └─ Final Fold Score: {np.round(final_fold_score, 2)}")

    # Final metrics
    mean_absolute_error = np.mean(all_absolute_errors)
    mean_portfolio_error = np.mean(all_portfolio_errors)
    final_score = np.mean(fold_scores)

    print("\n📊 Cross-Validation Summary")
    print(f"   ├─ Mean Absolute Error:  {mean_absolute_error:.2f}")
    print(f"   ├─ Mean Portfolio Error: {mean_portfolio_error:.2f}")
    print(f"   └─ Final CV Forecast Score: {np.round(final_score, 0)}")

    # print("FOLD_SCORES!!==========================")
    # print(fold_scores)

    # Create 1 row, 3 columns canvas
    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    # Plot 1: Fold Scores
    axs[0].plot(range(1, len(fold_scores) + 1), fold_scores, marker='o', linestyle='-')
    axs[0].set_title('Fold Scores')
    axs[0].set_xlabel('Fold')
    axs[0].set_ylabel('Score')
    axs[0].grid(True)

    # Plot 2: Absolute Errors
    axs[1].plot(range(1, len(all_absolute_errors) + 1), all_absolute_errors, marker='o', linestyle='-')
    axs[1].set_title('Absolute Errors')
    axs[1].set_xlabel('Fold')
    axs[1].set_ylabel('Absolute Error')
    axs[1].grid(True)

    # Plot 3: Portfolio Errors
    axs[2].plot(range(1, len(all_portfolio_errors) + 1), all_portfolio_errors, marker='o', linestyle='-')
    axs[2].set_title('Portfolio Errors')
    axs[2].set_xlabel('Fold')
    axs[2].set_ylabel('Portfolio Error')
    axs[2].grid(True)

    plt.tight_layout()

    # Save the plot
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
    plt.close()

    return mean_absolute_error, mean_portfolio_error, final_score


def evaluate(X: pd.DataFrame, y: pd.Series, save_path: str):
    # abs_err, port_err, score = cross_validate_forecaster(simple_predictor, training_set, features)
    abs_err, port_err, score = cross_validate_forecaster(
        predictor=lgbm_predictor,
        X=X,
        y=y,
        verbose=True,
        save_path=save_path,  # or None to just show the plot
    )

    return abs_err, port_err, score


def main(zone: str):
    """

    Train and evaluate the models for IT and ES

    """

    # Inputs
    input_path = r"datasets2025"
    output_path = r"outputs"

    # Load Datasets
    loader = DataLoader(input_path)
    # features are holidays and temperature
    training_set, features, example_results = loader.load_data(zone)

    """
    EVERYTHING STARTING FROM HERE CAN BE MODIFIED.
    """
    rollout, holidays = loader.load_additional_data(zone)
    # Add additional data to features

    team_name = "HANGUK_ML"
    # Data Manipulation and Training
    start_training = training_set.index.min()
    end_training = training_set.index.max()
    start_forecast, end_forecast = example_results.index[0], example_results.index[-1]

    dataset_encoding = DatasetEncoding(
        training_set,
        features,
        rollout,
        holidays,
        end_training=end_training,
        start_forecast=start_forecast,
        end_forecast=end_forecast,
    )

    range_forecast = pd.date_range(start=start_forecast, end=end_forecast, freq="1H")
    forecast = pd.DataFrame(columns=training_set.columns, index=range_forecast)
    forecast_step = 1
    errors = pd.DataFrame(
        columns=["abs_err", "port_err", "score"],
    )

    for costumer in training_set.columns.values:
        customer_id = int(costumer.split("_")[-1])
        print(f"******************************************")
        print(f"Start {customer_id}")

        df = dataset_encoding.generate_dataset(
            customer_id,
            window_size=24 * 7,
            forecast_skip=1,
            forecast_horizon=1,
            additional_feats=[
                "mean",
                "std",
                "skew",
                "kurtosis",
                "min",
                "max",
            ],
        )

        # evaluate
        X, y = dataset_encoding.get_train_data(df, customer_id, forecast_step=forecast_step, drop_nans_X=True)
        abs_err, port_err, score = evaluate(X, y, f"{output_path}/{customer_id}.png")
        errors.loc[customer_id] = [abs_err, port_err, score]
        print(f"errors: {errors.loc[customer_id]}")
        # consumption = training_set.loc[:, costumer]

        # feature_dummy = features["temp"].loc[start_training:]

        # encoding = SimpleEncoding(consumption, feature_dummy, end_training, start_forecast, end_forecast)

        # feature_past, feature_future, consumption_clean = encoding.meta_encoding()

        # # Train
        # model = SimpleModel()
        # model.train(feature_past, consumption_clean)

        # # Predict
        # output = model.predict(feature_future)
        # forecast[costumer] = output

    """
    END OF THE MODIFIABLE PART.
    """
    errors.to_csv(f"{output_path}/errors.csv")
    print(errors.mean())
    # # test to make sure that the output has the expected shape.
    # dummy_error = np.abs(forecast - example_results).sum().sum()
    # assert np.all(forecast.columns == example_results.columns), "Wrong header or header order."
    # assert np.all(forecast.index == example_results.index), "Wrong index or index order."
    # assert isinstance(dummy_error, np.float64), "Wrong dummy_error type."
    # assert forecast.isna().sum().sum() == 0, "NaN in forecast."
    # # Your solution will be evaluated using
    # # forecast_error = np.abs(forecast - testing_set).sum().sum(),
    # # and then doing a weighted sum the two portfolios:
    # # score = forecast_error_IT + 5 * forecast_error_ES

    # forecast.to_csv(join(output_path, "students_results_" + team_name + "_" + country + ".csv"))


if __name__ == "__main__":
    country = "IT"  # it can be ES or IT
    main(country)
# Out:
# /tmp/ipykernel_24953/3622975834.py:182: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   range_forecast = pd.date_range(start=start_forecast, end=end_forecast, freq="1H")
# ******************************************
# Start 1
#
# 📦 Fold 1/5
# ├─ Train range: 2023-07-08 00:00:00 → 2023-09-11 02:00:00  (1563 samples)
# └─ Test  range: 2023-09-11 03:00:00 → 2023-11-15 01:00:00  (1559 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (1563, 186) | y_train: (1563,)
#    │   X_test : (1559, 186) | y_test : (1559,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003580 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44722
# [LightGBM] [Info] Number of data points in the train set: 1563, number of used features: 186
# [LightGBM] [Info] Start training from score 0.008191
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  5.44
#    ├─ Mean Portfolio Error (per customer): 0.93
#    └─ Final Fold Score: 88.69
#
# 📦 Fold 2/5
# ├─ Train range: 2023-07-08 00:00:00 → 2023-11-15 01:00:00  (3122 samples)
# └─ Test  range: 2023-11-15 02:00:00 → 2024-01-19 00:00:00  (1559 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (3122, 186) | y_train: (3122,)
#    │   X_test : (1559, 186) | y_test : (1559,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003007 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44827
# [LightGBM] [Info] Number of data points in the train set: 3122, number of used features: 186
# [LightGBM] [Info] Start training from score 0.010830
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  6.20
#    ├─ Mean Portfolio Error (per customer): 1.56
#    └─ Final Fold Score: 130.86
#
# 📦 Fold 3/5
# ├─ Train range: 2023-07-08 00:00:00 → 2024-01-19 00:00:00  (4681 samples)
# └─ Test  range: 2024-01-19 01:00:00 → 2024-03-23 23:00:00  (1559 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (4681, 186) | y_train: (4681,)
#    │   X_test : (1559, 186) | y_test : (1559,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004326 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44891
# [LightGBM] [Info] Number of data points in the train set: 4681, number of used features: 186
# [LightGBM] [Info] Start training from score 0.011389
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  5.56
#    ├─ Mean Portfolio Error (per customer): 1.48
#    └─ Final Fold Score: 122.39
#
# 📦 Fold 4/5
# ├─ Train range: 2023-07-08 00:00:00 → 2024-03-23 23:00:00  (6240 samples)
# └─ Test  range: 2024-03-24 00:00:00 → 2024-05-27 23:00:00  (1559 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (6240, 186) | y_train: (6240,)
#    │   X_test : (1559, 186) | y_test : (1559,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004078 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44930
# [LightGBM] [Info] Number of data points in the train set: 6240, number of used features: 186
# [LightGBM] [Info] Start training from score 0.012959
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  6.51
#    ├─ Mean Portfolio Error (per customer): 0.21
#    └─ Final Fold Score: 51.89
#
# 📦 Fold 5/5
# ├─ Train range: 2023-07-08 00:00:00 → 2024-05-27 23:00:00  (7799 samples)
# └─ Test  range: 2024-05-28 00:00:00 → 2024-07-31 22:00:00  (1559 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (7799, 186) | y_train: (7799,)
#    │   X_test : (1559, 186) | y_test : (1559,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005018 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44970
# [LightGBM] [Info] Number of data points in the train set: 7799, number of used features: 186
# [LightGBM] [Info] Start training from score 0.013153
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  5.09
#    ├─ Mean Portfolio Error (per customer): 0.05
#    └─ Final Fold Score: 33.81
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  5.76
#    ├─ Mean Portfolio Error: 0.85
#    └─ Final CV Forecast Score: 86.0
# errors: abs_err      5.758308
# port_err     0.849606
# score       85.526187
# Name: 1, dtype: float64
# ******************************************
# Start 2
#
# 📦 Fold 1/5
# ├─ Train range: 2023-01-08 00:00:00 → 2023-04-13 06:00:00  (2286 samples)
# └─ Test  range: 2023-04-13 07:00:00 → 2023-07-17 09:00:00  (2283 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (2286, 186) | y_train: (2286,)
#    │   X_test : (2283, 186) | y_test : (2283,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002661 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44708
# [LightGBM] [Info] Number of data points in the train set: 2286, number of used features: 186
# [LightGBM] [Info] Start training from score 0.005307
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  2.79
#    ├─ Mean Portfolio Error (per customer): 1.42
#    └─ Final Fold Score: 102.19
#
# 📦 Fold 2/5
# ├─ Train range: 2023-01-08 00:00:00 → 2023-07-17 09:00:00  (4569 samples)
# └─ Test  range: 2023-07-17 10:00:00 → 2023-10-20 12:00:00  (2283 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (4569, 186) | y_train: (4569,)
#    │   X_test : (2283, 186) | y_test : (2283,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002568 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44796
# [LightGBM] [Info] Number of data points in the train set: 4569, number of used features: 186
# [LightGBM] [Info] Start training from score 0.005361
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  2.55
#    ├─ Mean Portfolio Error (per customer): 0.44
#    └─ Final Fold Score: 41.74
#
# 📦 Fold 3/5
# ├─ Train range: 2023-01-08 00:00:00 → 2023-10-20 12:00:00  (6852 samples)
# └─ Test  range: 2023-10-20 13:00:00 → 2024-01-23 15:00:00  (2283 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (6852, 186) | y_train: (6852,)
#    │   X_test : (2283, 186) | y_test : (2283,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003868 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44839
# [LightGBM] [Info] Number of data points in the train set: 6852, number of used features: 186
# [LightGBM] [Info] Start training from score 0.005689
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  1.17
#    ├─ Mean Portfolio Error (per customer): 0.09
#    └─ Final Fold Score: 12.54
#
# 📦 Fold 4/5
# ├─ Train range: 2023-01-08 00:00:00 → 2024-01-23 15:00:00  (9135 samples)
# └─ Test  range: 2024-01-23 16:00:00 → 2024-04-27 19:00:00  (2283 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (9135, 186) | y_train: (9135,)
#    │   X_test : (2283, 186) | y_test : (2283,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44862
# [LightGBM] [Info] Number of data points in the train set: 9135, number of used features: 186
# [LightGBM] [Info] Start training from score 0.005618
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  1.05
#    ├─ Mean Portfolio Error (per customer): 0.13
#    └─ Final Fold Score: 13.97
#
# 📦 Fold 5/5
# ├─ Train range: 2023-01-08 00:00:00 → 2024-04-27 19:00:00  (11418 samples)
# └─ Test  range: 2024-04-27 20:00:00 → 2024-07-31 22:00:00  (2283 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (11418, 186) | y_train: (11418,)
#    │   X_test : (2283, 186) | y_test : (2283,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006806 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44882
# [LightGBM] [Info] Number of data points in the train set: 11418, number of used features: 186
# [LightGBM] [Info] Start training from score 0.005569
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  1.13
#    ├─ Mean Portfolio Error (per customer): 0.01
#    └─ Final Fold Score: 7.2
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  1.74
#    ├─ Mean Portfolio Error: 0.42
#    └─ Final CV Forecast Score: 36.0
# errors: abs_err      1.738231
# port_err     0.418326
# score       35.528946
# Name: 2, dtype: float64
# ******************************************
# Start 3
#
# 📦 Fold 1/5
# ├─ Train range: 2022-10-08 00:00:00 → 2023-01-26 13:00:00  (2654 samples)
# └─ Test  range: 2023-01-26 14:00:00 → 2023-05-17 01:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (2654, 186) | y_train: (2654,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003441 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44887
# [LightGBM] [Info] Number of data points in the train set: 2654, number of used features: 186
# [LightGBM] [Info] Start training from score 0.120093
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  17.29
#    ├─ Mean Portfolio Error (per customer): 0.60
#    └─ Final Fold Score: 139.85
#
# 📦 Fold 2/5
# ├─ Train range: 2022-10-08 00:00:00 → 2023-05-17 01:00:00  (5305 samples)
# └─ Test  range: 2023-05-17 02:00:00 → 2023-09-04 12:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (5305, 186) | y_train: (5305,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005482 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45006
# [LightGBM] [Info] Number of data points in the train set: 5305, number of used features: 186
# [LightGBM] [Info] Start training from score 0.118677
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  45.36
#    ├─ Mean Portfolio Error (per customer): 28.32
#    └─ Final Fold Score: 1971.59
#
# 📦 Fold 3/5
# ├─ Train range: 2022-10-08 00:00:00 → 2023-09-04 12:00:00  (7956 samples)
# └─ Test  range: 2023-09-04 13:00:00 → 2023-12-23 23:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (7956, 186) | y_train: (7956,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008221 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45141
# [LightGBM] [Info] Number of data points in the train set: 7956, number of used features: 186
# [LightGBM] [Info] Start training from score 0.124888
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  14.13
#    ├─ Mean Portfolio Error (per customer): 0.22
#    └─ Final Fold Score: 97.96
#
# 📦 Fold 4/5
# ├─ Train range: 2022-10-08 00:00:00 → 2023-12-23 23:00:00  (10607 samples)
# └─ Test  range: 2023-12-24 00:00:00 → 2024-04-12 11:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (10607, 186) | y_train: (10607,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007649 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45208
# [LightGBM] [Info] Number of data points in the train set: 10607, number of used features: 186
# [LightGBM] [Info] Start training from score 0.127488
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  11.87
#    ├─ Mean Portfolio Error (per customer): 0.06
#    └─ Final Fold Score: 74.9
#
# 📦 Fold 5/5
# ├─ Train range: 2022-10-08 00:00:00 → 2024-04-12 11:00:00  (13258 samples)
# └─ Test  range: 2024-04-12 12:00:00 → 2024-07-31 22:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (13258, 186) | y_train: (13258,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008250 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45319
# [LightGBM] [Info] Number of data points in the train set: 13258, number of used features: 186
# [LightGBM] [Info] Start training from score 0.126081
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  23.93
#    ├─ Mean Portfolio Error (per customer): 1.49
#    └─ Final Fold Score: 232.79
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  22.52
#    ├─ Mean Portfolio Error: 6.14
#    └─ Final CV Forecast Score: 503.0
# errors: abs_err      22.515713
# port_err      6.138712
# score       503.416986
# Name: 3, dtype: float64
# ******************************************
# Start 4
#
# 📦 Fold 1/5
# ├─ Train range: 2022-10-08 00:00:00 → 2023-01-26 13:00:00  (2654 samples)
# └─ Test  range: 2023-01-26 14:00:00 → 2023-05-17 01:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (2654, 186) | y_train: (2654,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002019 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44954
# [LightGBM] [Info] Number of data points in the train set: 2654, number of used features: 186
# [LightGBM] [Info] Start training from score 0.218219
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  62.47
#    ├─ Mean Portfolio Error (per customer): 3.86
#    └─ Final Fold Score: 606.45
#
# 📦 Fold 2/5
# ├─ Train range: 2022-10-08 00:00:00 → 2023-05-17 01:00:00  (5305 samples)
# └─ Test  range: 2023-05-17 02:00:00 → 2023-09-04 12:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (5305, 186) | y_train: (5305,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004077 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45015
# [LightGBM] [Info] Number of data points in the train set: 5305, number of used features: 186
# [LightGBM] [Info] Start training from score 0.204233
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  80.60
#    ├─ Mean Portfolio Error (per customer): 11.18
#    └─ Final Fold Score: 1154.36
#
# 📦 Fold 3/5
# ├─ Train range: 2022-10-08 00:00:00 → 2023-09-04 12:00:00  (7956 samples)
# └─ Test  range: 2023-09-04 13:00:00 → 2023-12-23 23:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (7956, 186) | y_train: (7956,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45086
# [LightGBM] [Info] Number of data points in the train set: 7956, number of used features: 186
# [LightGBM] [Info] Start training from score 0.201760
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  53.61
#    ├─ Mean Portfolio Error (per customer): 8.38
#    └─ Final Fold Score: 824.38
#
# 📦 Fold 4/5
# ├─ Train range: 2022-10-08 00:00:00 → 2023-12-23 23:00:00  (10607 samples)
# └─ Test  range: 2023-12-24 00:00:00 → 2024-04-12 11:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (10607, 186) | y_train: (10607,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008219 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45130
# [LightGBM] [Info] Number of data points in the train set: 10607, number of used features: 186
# [LightGBM] [Info] Start training from score 0.216064
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  54.11
#    ├─ Mean Portfolio Error (per customer): 12.73
#    └─ Final Fold Score: 1088.26
#
# 📦 Fold 5/5
# ├─ Train range: 2022-10-08 00:00:00 → 2024-04-12 11:00:00  (13258 samples)
# └─ Test  range: 2024-04-12 12:00:00 → 2024-07-31 22:00:00  (2651 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (13258, 186) | y_train: (13258,)
#    │   X_test : (2651, 186) | y_test : (2651,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012293 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45167
# [LightGBM] [Info] Number of data points in the train set: 13258, number of used features: 186
# [LightGBM] [Info] Start training from score 0.216404
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  67.75
#    ├─ Mean Portfolio Error (per customer): 9.60
#    └─ Final Fold Score: 982.58
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  63.71
#    ├─ Mean Portfolio Error: 9.15
#    └─ Final CV Forecast Score: 931.0
# errors: abs_err      63.709545
# port_err      9.149202
# score       931.209371
# Name: 4, dtype: float64
# ******************************************
# Start 5
#
# 📦 Fold 1/5
# ├─ Train range: 2023-01-08 00:00:00 → 2023-04-10 18:00:00  (2226 samples)
# └─ Test  range: 2023-04-10 19:00:00 → 2023-07-12 09:00:00  (2223 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (2226, 186) | y_train: (2226,)
#    │   X_test : (2223, 186) | y_test : (2223,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002702 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 39579
# [LightGBM] [Info] Number of data points in the train set: 2226, number of used features: 185
# [LightGBM] [Info] Start training from score 0.008947
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  2.10
#    ├─ Mean Portfolio Error (per customer): 1.39
#    └─ Final Fold Score: 96.27
#
# 📦 Fold 2/5
# ├─ Train range: 2023-01-08 00:00:00 → 2023-07-12 09:00:00  (4449 samples)
# └─ Test  range: 2023-07-12 10:00:00 → 2023-10-13 00:00:00  (2223 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (4449, 186) | y_train: (4449,)
#    │   X_test : (2223, 186) | y_test : (2223,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002818 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44729
# [LightGBM] [Info] Number of data points in the train set: 4449, number of used features: 186
# [LightGBM] [Info] Start training from score 0.009224
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  2.00
#    ├─ Mean Portfolio Error (per customer): 0.28
#    └─ Final Fold Score: 28.86
#
# 📦 Fold 3/5
# ├─ Train range: 2023-01-08 00:00:00 → 2023-10-13 00:00:00  (6672 samples)
# └─ Test  range: 2023-10-13 01:00:00 → 2024-01-28 15:00:00  (2223 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (6672, 186) | y_train: (6672,)
#    │   X_test : (2223, 186) | y_test : (2223,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007903 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44836
# [LightGBM] [Info] Number of data points in the train set: 6672, number of used features: 186
# [LightGBM] [Info] Start training from score 0.009514
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  1.19
#    ├─ Mean Portfolio Error (per customer): 0.10
#    └─ Final Fold Score: 13.35
#
# 📦 Fold 4/5
# ├─ Train range: 2023-01-08 00:00:00 → 2024-01-28 15:00:00  (8895 samples)
# └─ Test  range: 2024-01-28 16:00:00 → 2024-04-30 07:00:00  (2223 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (8895, 186) | y_train: (8895,)
#    │   X_test : (2223, 186) | y_test : (2223,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007482 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44865
# [LightGBM] [Info] Number of data points in the train set: 8895, number of used features: 186
# [LightGBM] [Info] Start training from score 0.009316
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  1.28
#    ├─ Mean Portfolio Error (per customer): 0.20
#    └─ Final Fold Score: 19.57
#
# 📦 Fold 5/5
# ├─ Train range: 2023-01-08 00:00:00 → 2024-04-30 07:00:00  (11118 samples)
# └─ Test  range: 2024-04-30 08:00:00 → 2024-07-31 22:00:00  (2223 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (11118, 186) | y_train: (11118,)
#    │   X_test : (2223, 186) | y_test : (2223,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015529 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44887
# [LightGBM] [Info] Number of data points in the train set: 11118, number of used features: 186
# [LightGBM] [Info] Start training from score 0.009227
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  1.31
#    ├─ Mean Portfolio Error (per customer): 0.11
#    └─ Final Fold Score: 14.73
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  1.58
#    ├─ Mean Portfolio Error: 0.42
#    └─ Final CV Forecast Score: 35.0
# errors: abs_err      1.577635
# port_err     0.418185
# score       34.556894
# Name: 5, dtype: float64
# ******************************************
# Start 6
#
# 📦 Fold 1/5
# ├─ Train range: 2022-01-14 23:00:00 → 2022-06-18 21:00:00  (3718 samples)
# └─ Test  range: 2022-06-18 22:00:00 → 2022-11-20 16:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (3718, 186) | y_train: (3718,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002336 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44816
# [LightGBM] [Info] Number of data points in the train set: 3718, number of used features: 186
# [LightGBM] [Info] Start training from score 0.129918
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  37.09
#    ├─ Mean Portfolio Error (per customer): 13.03
#    └─ Final Fold Score: 1004.44
#
# 📦 Fold 2/5
# ├─ Train range: 2022-01-14 23:00:00 → 2022-11-20 16:00:00  (7433 samples)
# └─ Test  range: 2022-11-20 17:00:00 → 2023-04-24 12:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (7433, 186) | y_train: (7433,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006178 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44924
# [LightGBM] [Info] Number of data points in the train set: 7433, number of used features: 186
# [LightGBM] [Info] Start training from score 0.156761
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  77.35
#    ├─ Mean Portfolio Error (per customer): 52.08
#    └─ Final Fold Score: 3588.79
#
# 📦 Fold 3/5
# ├─ Train range: 2022-01-14 23:00:00 → 2023-04-24 12:00:00  (11148 samples)
# └─ Test  range: 2023-04-24 13:00:00 → 2023-09-26 07:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (11148, 186) | y_train: (11148,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44991
# [LightGBM] [Info] Number of data points in the train set: 11148, number of used features: 186
# [LightGBM] [Info] Start training from score 0.129237
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  62.06
#    ├─ Mean Portfolio Error (per customer): 8.38
#    └─ Final Fold Score: 875.46
#
# 📦 Fold 4/5
# ├─ Train range: 2022-01-14 23:00:00 → 2023-09-26 07:00:00  (14863 samples)
# └─ Test  range: 2023-09-26 08:00:00 → 2024-02-28 02:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (14863, 186) | y_train: (14863,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45053
# [LightGBM] [Info] Number of data points in the train set: 14863, number of used features: 186
# [LightGBM] [Info] Start training from score 0.124523
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  30.92
#    ├─ Mean Portfolio Error (per customer): 0.85
#    └─ Final Fold Score: 236.72
#
# 📦 Fold 5/5
# ├─ Train range: 2022-01-14 23:00:00 → 2024-02-28 02:00:00  (18578 samples)
# └─ Test  range: 2024-02-28 03:00:00 → 2024-07-31 22:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (18578, 186) | y_train: (18578,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.018896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45143
# [LightGBM] [Info] Number of data points in the train set: 18578, number of used features: 186
# [LightGBM] [Info] Start training from score 0.114733
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  49.99
#    ├─ Mean Portfolio Error (per customer): 5.79
#    └─ Final Fold Score: 647.44
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  51.48
#    ├─ Mean Portfolio Error: 16.03
#    └─ Final CV Forecast Score: 1271.0
# errors: abs_err       51.482390
# port_err      16.027931
# score       1270.570187
# Name: 6, dtype: float64
# ******************************************
# Start 7
#
# 📦 Fold 1/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-02-11 10:00:00  (827 samples)
# └─ Test  range: 2024-02-11 11:00:00 → 2024-03-16 17:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (827, 186) | y_train: (827,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001794 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44572
# [LightGBM] [Info] Number of data points in the train set: 827, number of used features: 185
# [LightGBM] [Info] Start training from score 0.225878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  15.68
#    ├─ Mean Portfolio Error (per customer): 1.20
#    └─ Final Fold Score: 166.01
#
# 📦 Fold 2/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-03-16 17:00:00  (1650 samples)
# └─ Test  range: 2024-03-16 18:00:00 → 2024-04-20 01:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (1650, 186) | y_train: (1650,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44807
# [LightGBM] [Info] Number of data points in the train set: 1650, number of used features: 185
# [LightGBM] [Info] Start training from score 0.221014
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  17.71
#    ├─ Mean Portfolio Error (per customer): 8.23
#    └─ Final Fold Score: 600.3
#
# 📦 Fold 3/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-04-20 01:00:00  (2473 samples)
# └─ Test  range: 2024-04-20 02:00:00 → 2024-05-24 08:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (2473, 186) | y_train: (2473,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002800 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44923
# [LightGBM] [Info] Number of data points in the train set: 2473, number of used features: 186
# [LightGBM] [Info] Start training from score 0.207708
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  10.68
#    ├─ Mean Portfolio Error (per customer): 2.58
#    └─ Final Fold Score: 219.17
#
# 📦 Fold 4/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-05-24 08:00:00  (3296 samples)
# └─ Test  range: 2024-05-24 09:00:00 → 2024-06-27 15:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (3296, 186) | y_train: (3296,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44980
# [LightGBM] [Info] Number of data points in the train set: 3296, number of used features: 186
# [LightGBM] [Info] Start training from score 0.196422
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  9.29
#    ├─ Mean Portfolio Error (per customer): 0.24
#    └─ Final Fold Score: 69.9
#
# 📦 Fold 5/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-06-27 15:00:00  (4119 samples)
# └─ Test  range: 2024-06-27 16:00:00 → 2024-07-31 22:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (4119, 186) | y_train: (4119,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003494 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45017
# [LightGBM] [Info] Number of data points in the train set: 4119, number of used features: 186
# [LightGBM] [Info] Start training from score 0.188951
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  11.93
#    ├─ Mean Portfolio Error (per customer): 1.56
#    └─ Final Fold Score: 165.36
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  13.06
#    ├─ Mean Portfolio Error: 2.76
#    └─ Final CV Forecast Score: 244.0
# errors: abs_err      13.058135
# port_err      2.763306
# score       244.147166
# Name: 7, dtype: float64
# ******************************************
# Start 8
#
# 📦 Fold 1/5
# ├─ Train range: 2022-01-14 23:00:00 → 2022-06-18 21:00:00  (3718 samples)
# └─ Test  range: 2022-06-18 22:00:00 → 2022-11-20 16:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (3718, 186) | y_train: (3718,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003959 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44742
# [LightGBM] [Info] Number of data points in the train set: 3718, number of used features: 185
# [LightGBM] [Info] Start training from score 0.027151
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  32.69
#    ├─ Mean Portfolio Error (per customer): 5.55
#    └─ Final Fold Score: 529.03
#
# 📦 Fold 2/5
# ├─ Train range: 2022-01-14 23:00:00 → 2022-11-20 16:00:00  (7433 samples)
# └─ Test  range: 2022-11-20 17:00:00 → 2023-04-24 12:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (7433, 186) | y_train: (7433,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010174 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44794
# [LightGBM] [Info] Number of data points in the train set: 7433, number of used features: 185
# [LightGBM] [Info] Start training from score 0.025596
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  94.36
#    ├─ Mean Portfolio Error (per customer): 38.29
#    └─ Final Fold Score: 2863.29
#
# 📦 Fold 3/5
# ├─ Train range: 2022-01-14 23:00:00 → 2023-04-24 12:00:00  (11148 samples)
# └─ Test  range: 2023-04-24 13:00:00 → 2023-09-26 07:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (11148, 186) | y_train: (11148,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44840
# [LightGBM] [Info] Number of data points in the train set: 11148, number of used features: 185
# [LightGBM] [Info] Start training from score 0.037123
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  21.69
#    ├─ Mean Portfolio Error (per customer): 0.37
#    └─ Final Fold Score: 152.08
#
# 📦 Fold 4/5
# ├─ Train range: 2022-01-14 23:00:00 → 2023-09-26 07:00:00  (14863 samples)
# └─ Test  range: 2023-09-26 08:00:00 → 2024-02-28 02:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (14863, 186) | y_train: (14863,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019822 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44903
# [LightGBM] [Info] Number of data points in the train set: 14863, number of used features: 186
# [LightGBM] [Info] Start training from score 0.032232
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  53.26
#    ├─ Mean Portfolio Error (per customer): 10.47
#    └─ Final Fold Score: 947.77
#
# 📦 Fold 5/5
# ├─ Train range: 2022-01-14 23:00:00 → 2024-02-28 02:00:00  (18578 samples)
# └─ Test  range: 2024-02-28 03:00:00 → 2024-07-31 22:00:00  (3715 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (18578, 186) | y_train: (18578,)
#    │   X_test : (3715, 186) | y_test : (3715,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031822 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44942
# [LightGBM] [Info] Number of data points in the train set: 18578, number of used features: 186
# [LightGBM] [Info] Start training from score 0.038240
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  33.31
#    ├─ Mean Portfolio Error (per customer): 2.73
#    └─ Final Fold Score: 363.53
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  47.06
#    ├─ Mean Portfolio Error: 11.48
#    └─ Final CV Forecast Score: 971.0
# errors: abs_err      47.064899
# port_err     11.479171
# score       971.139677
# Name: 8, dtype: float64
# ******************************************
# Start 13
#
# 📦 Fold 1/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-02-11 10:00:00  (827 samples)
# └─ Test  range: 2024-02-11 11:00:00 → 2024-03-16 17:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (827, 186) | y_train: (827,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001891 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 43970
# [LightGBM] [Info] Number of data points in the train set: 827, number of used features: 185
# [LightGBM] [Info] Start training from score 0.042035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  3.98
#    ├─ Mean Portfolio Error (per customer): 1.03
#    └─ Final Fold Score: 85.65
#
# 📦 Fold 2/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-03-16 17:00:00  (1650 samples)
# └─ Test  range: 2024-03-16 18:00:00 → 2024-04-20 01:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (1650, 186) | y_train: (1650,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003974 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44710
# [LightGBM] [Info] Number of data points in the train set: 1650, number of used features: 185
# [LightGBM] [Info] Start training from score 0.041812
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  7.64
#    ├─ Mean Portfolio Error (per customer): 2.48
#    └─ Final Fold Score: 194.39
#
# 📦 Fold 3/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-04-20 01:00:00  (2473 samples)
# └─ Test  range: 2024-04-20 02:00:00 → 2024-05-24 08:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (2473, 186) | y_train: (2473,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003583 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44786
# [LightGBM] [Info] Number of data points in the train set: 2473, number of used features: 186
# [LightGBM] [Info] Start training from score 0.039281
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  6.81
#    ├─ Mean Portfolio Error (per customer): 0.46
#    └─ Final Fold Score: 68.56
#
# 📦 Fold 4/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-05-24 08:00:00  (3296 samples)
# └─ Test  range: 2024-05-24 09:00:00 → 2024-06-27 15:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (3296, 186) | y_train: (3296,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003238 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44827
# [LightGBM] [Info] Number of data points in the train set: 3296, number of used features: 186
# [LightGBM] [Info] Start training from score 0.037433
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  3.19
#    ├─ Mean Portfolio Error (per customer): 0.15
#    └─ Final Fold Score: 28.39
#
# 📦 Fold 5/5
# ├─ Train range: 2024-01-08 00:00:00 → 2024-06-27 15:00:00  (4119 samples)
# └─ Test  range: 2024-06-27 16:00:00 → 2024-07-31 22:00:00  (823 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (4119, 186) | y_train: (4119,)
#    │   X_test : (823, 186) | y_test : (823,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003852 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44856
# [LightGBM] [Info] Number of data points in the train set: 4119, number of used features: 186
# [LightGBM] [Info] Start training from score 0.036814
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  2.96
#    ├─ Mean Portfolio Error (per customer): 0.32
#    └─ Final Fold Score: 36.77
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  4.92
#    ├─ Mean Portfolio Error: 0.89
#    └─ Final CV Forecast Score: 83.0
# errors: abs_err      4.915681
# port_err     0.887632
# score       82.751988
# Name: 13, dtype: float64
# ******************************************
# Start 14
#
# 📦 Fold 1/5
# ├─ Train range: 2022-08-08 00:00:00 → 2022-12-06 17:00:00  (2898 samples)
# └─ Test  range: 2022-12-06 18:00:00 → 2023-04-06 09:00:00  (2895 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (2898, 186) | y_train: (2898,)
#    │   X_test : (2895, 186) | y_test : (2895,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002494 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44896
# [LightGBM] [Info] Number of data points in the train set: 2898, number of used features: 186
# [LightGBM] [Info] Start training from score 0.048842
#
# ✅ Fold 1 completed
#    ├─ Mean Absolute Error (per customer):  13.05
#    ├─ Mean Portfolio Error (per customer): 1.24
#    └─ Final Fold Score: 153.01
#
# 📦 Fold 2/5
# ├─ Train range: 2022-08-08 00:00:00 → 2023-04-06 09:00:00  (5793 samples)
# └─ Test  range: 2023-04-06 10:00:00 → 2023-08-05 00:00:00  (2895 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (5793, 186) | y_train: (5793,)
#    │   X_test : (2895, 186) | y_test : (2895,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005467 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 44983
# [LightGBM] [Info] Number of data points in the train set: 5793, number of used features: 186
# [LightGBM] [Info] Start training from score 0.049660
#
# ✅ Fold 2 completed
#    ├─ Mean Absolute Error (per customer):  16.63
#    ├─ Mean Portfolio Error (per customer): 5.78
#    └─ Final Fold Score: 446.63
#
# 📦 Fold 3/5
# ├─ Train range: 2022-08-08 00:00:00 → 2023-08-05 00:00:00  (8688 samples)
# └─ Test  range: 2023-08-05 01:00:00 → 2023-12-03 15:00:00  (2895 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (8688, 186) | y_train: (8688,)
#    │   X_test : (2895, 186) | y_test : (2895,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010432 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45034
# [LightGBM] [Info] Number of data points in the train set: 8688, number of used features: 186
# [LightGBM] [Info] Start training from score 0.052320
#
# ✅ Fold 3 completed
#    ├─ Mean Absolute Error (per customer):  11.05
#    ├─ Mean Portfolio Error (per customer): 0.36
#    └─ Final Fold Score: 87.86
#
# 📦 Fold 4/5
# ├─ Train range: 2022-08-08 00:00:00 → 2023-12-03 15:00:00  (11583 samples)
# └─ Test  range: 2023-12-03 16:00:00 → 2024-04-02 07:00:00  (2895 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (11583, 186) | y_train: (11583,)
#    │   X_test : (2895, 186) | y_test : (2895,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015116 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45076
# [LightGBM] [Info] Number of data points in the train set: 11583, number of used features: 186
# [LightGBM] [Info] Start training from score 0.052925
#
# ✅ Fold 4 completed
#    ├─ Mean Absolute Error (per customer):  11.46
#    ├─ Mean Portfolio Error (per customer): 1.55
#    └─ Final Fold Score: 161.77
#
# 📦 Fold 5/5
# ├─ Train range: 2022-08-08 00:00:00 → 2024-04-02 07:00:00  (14478 samples)
# └─ Test  range: 2024-04-02 08:00:00 → 2024-07-31 22:00:00  (2895 samples)
#    ┌── Data shapes for first customer:
#    │   X_train: (14478, 186) | y_train: (14478,)
#    │   X_test : (2895, 186) | y_test : (2895,)
#    └──────────────────────────────
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014998 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 45104
# [LightGBM] [Info] Number of data points in the train set: 14478, number of used features: 186
# [LightGBM] [Info] Start training from score 0.053156
#
# ✅ Fold 5 completed
#    ├─ Mean Absolute Error (per customer):  13.69
#    ├─ Mean Portfolio Error (per customer): 3.41
#    └─ Final Fold Score: 286.5
#
# 📊 Cross-Validation Summary
#    ├─ Mean Absolute Error:  13.18
#    ├─ Mean Portfolio Error: 2.47
#    └─ Final CV Forecast Score: 227.0
